# %% [markdown]
# # list in python

# %%
robots = ["Alpha", "Beta", "Gamma"]

print("Robot List:", robots)
print("First Robot:", robots[0])
print("Second Robot:", robots[1])
print("Last Robot:", robots[-1])
robots.append("Delta")
robots.remove("Beta")
print("Updated Robot List:", robots)
# Out:
# Robot List: ['Alpha', 'Beta', 'Gamma']
# First Robot: Alpha
# Second Robot: Beta
# Last Robot: Gamma
# Updated Robot List: ['Alpha', 'Gamma', 'Delta']

# %% [markdown]
# # Try Self

# %%
fruits = ["Apple", "Grapes", "Bannana", "Mango", "Orange"]

print("Fruit List:", fruits)
print("First Fruit:", fruits[0])
print("Last Fruit:", fruits[1])
fruits.append("Blueberry")
fruits.remove("Apple")
print("Update Fruit List:", fruits)
# Out:
# Fruit List: ['Apple', 'Grapes', 'Bannana', 'Mango', 'Orange']
# First Fruit: Apple
# Last Fruit: Grapes
# Update Fruit List: ['Grapes', 'Bannana', 'Mango', 'Orange', 'Blueberry']

# %% [markdown]
# # Dictionary in Python

# %%
robot = {"name": "Alpha", "battery": 80, "status": "Active"}

print("Robot Name:", robot["name"])
print("Battery Level:", robot["battery"])
print("status:", robot["status"])
# Out:
# Robot Name: Alpha
# Battery Level: 80
# status: Active

# %% [markdown]
# # Loops in python

# %%
battery = 5
while battery > 0:
    print("Battery remaining:", battery)
    battery -= 1
# Out:
# Battery remaining: 5
# Battery remaining: 4
# Battery remaining: 3
# Battery remaining: 2
# Battery remaining: 1

# %% [markdown]
# # Data comparison

# %%
battery = 40

if battery > 60:
    print("Battery is Full - Ready for Mission!")
elif battery > 30:
    print("Battery is Medium - Prepare for Recharge")
else:
    print("Battery Low - Returning to Base")
# Out:
# Battery is Medium - Prepare for Recharge

# %% [markdown]
# # Mini AI Project

# %%
robots = {"Alpha": 75, "Beta": 20, "Gamma": 60}
for name, battery in robots.items():
    if battery > 50:
        print(name, "→ Battery OK  (", battery, "%)")
    else:
         print(name, "→ Low Battery  (", battery, "%)")
# Out:
# Alpha → Battery OK  ( 75 %)
# Beta → Low Battery  ( 20 %)
# Gamma → Battery OK  ( 60 %)
