# %%
class SequentialSearch:
    def __init__(my , data):
        my.data = data

    def search(my , target):
        for index in range(len(my.data)):
            if my.data[index] == target:
                return index
        return -1

arr = [15,8,23,42,4,33]
obj = SequentialSearch(arr)

print(obj.search(33))
print(obj.search(99))
# Out:
# 5
# -1

# %%
class SequentialSearch:
    def __init__(my , data):
        my.data = data

    def search(my , target):
        count = 0;
        for index in range(len(my.data)):
            count +=1
            if my.data[index] == target:
                return count
        return -1

arr = [15,8,23,42,4,33,45,667,43,43,67]
obj = SequentialSearch(arr)

print("33 find after taking ", obj.search(33), "Counts.")
print("99 find after taking ", obj.search(99), "Counts.")
print("34 find after taking ", obj.search(34), "Counts.")
print("45 find after taking ", obj.search(45), "Counts.")
print("32 find after taking ", obj.search(32), "Counts.")
# Out:
# 33 find after taking  6 Counts.
# 99 find after taking  -1 Counts.
# 34 find after taking  -1 Counts.
# 45 find after taking  7 Counts.
# 32 find after taking  -1 Counts.

# %%
class SequentialSearch:
    def __init__(my , data):
        my.data = data

    def search(my , target):
        count = 0;
        for index in range(len(my.data)):
            count +=1
            if my.data[index] == target:
                return count
        return -1

arr = [15,8,23,42,4,34]
obj = SequentialSearch(arr)

size = len(arr)
mid = 0 + (size // 2)
for val in arr:
    search_ele = obj.search(val)
    if search_ele == 1:
        print(f"{val} is the first element. Its take 1 counts.")
    elif search_ele == size:
        print(f"{val} is the last element. Its take {size} counts.")
    elif search_ele == mid:
        print(f"{val} is the middel element. Its take {mid} counts.")
    elif search_ele == -1:
        print(f"{val} is the not found.")
    else:
        print(f"{val} take {search_ele} counts.")
# Out:
# 15 is the first element. Its take 1 counts.
# 8 take 2 counts.
# 23 is the middel element. Its take 3 counts.
# 42 take 4 counts.
# 4 take 5 counts.
# 34 is the last element. Its take 6 counts.

# %%
class BinarySearch:
    def __init__(my , data):
        my.data = sorted(data)

    def search(my , target):
        low = 0
        high = len(my.data) - 1

        while low <= high :
            mid = low + (high - low ) // 2
            print("mid: ",mid)
            if my.data[mid] > target:
                high = mid -1
            elif my.data[mid] < target :
                low = mid + 1
            else:
                return mid

        return -1

arr = [15, 8, 23, 42, 4, 33]
print(sorted(arr))
obj = BinarySearch(arr)

print(obj.search(23))
print(obj.search(42))
print(obj.search(99))
# Out:
# [4, 8, 15, 23, 33, 42]
# mid:  2
# mid:  4
# mid:  3
# 3
# mid:  2
# mid:  4
# mid:  5
# 5
# mid:  2
# mid:  4
# mid:  5
# -1

# %%
class BinarySearch:
    def __init__(my , data):
        my.data = sorted(data)

    def search(my , target):
        low = 0
        high = len(my.data) - 1
        count = 0
        while low <= high :
            mid = low + (high - low ) // 2

            count +=1
            
            if my.data[mid] > target:
                high = mid -1
            elif my.data[mid] < target :
                low = mid + 1
            else:
                return mid , count

        return -1

arr = [15, 8, 23, 42, 4, 33]
print(sorted(arr))
obj = BinarySearch(arr)

search_ele = obj.search(23)
print(f"23 is at index : {search_ele[0]}  and it has {search_ele[1]} counts.\n" )
search_ele = obj.search(42)
print(f"42 is at index : {search_ele[0]}  and it has {search_ele[1]} counts.\n" )
search_ele = obj.search(99)
print(f"99 is not found {search_ele}")
# Out:
# [4, 8, 15, 23, 33, 42]
# 23 is at index : 3  and it has 3 counts.
#
# 42 is at index : 5  and it has 3 counts.
#
# 99 is not found -1

# %%
# Sequential Search for same array.
seqObj = SequentialSearch(arr)

seq_search_ele = seqObj.search(42)
bin_search_ele = obj.search(42)

print(f"42 has : {bin_search_ele[1]} counts in Binary Search.\n42 has : {seq_search_ele} counts in sequential Search.\n" )
# Out:
# 42 has : 3 counts in Binary Search.
# 42 has : 4 counts in sequential Search.
